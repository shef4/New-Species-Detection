# %%
pip install librosa
# Out:
# Requirement already satisfied: librosa in c:\users\sefun\anaconda3\lib\site-packages (0.7.2)
# Requirement already satisfied: decorator>=3.0.0 in c:\users\sefun\anaconda3\lib\site-packages (from librosa) (4.4.1)
# Requirement already satisfied: audioread>=2.0.0 in c:\users\sefun\anaconda3\lib\site-packages (from librosa) (2.1.8)
# Requirement already satisfied: numba>=0.43.0 in c:\users\sefun\anaconda3\lib\site-packages (from librosa) (0.48.0)
# Requirement already satisfied: joblib>=0.12 in c:\users\sefun\anaconda3\lib\site-packages (from librosa) (0.14.1)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\sefun\anaconda3\lib\site-packages (from librosa) (1.18.4)
# Requirement already satisfied: scikit-learn!=0.19.0,>=0.14.0 in c:\users\sefun\anaconda3\lib\site-packages (from librosa) (0.22.1)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\sefun\anaconda3\lib\site-packages (from librosa) (1.4.1)
# Requirement already satisfied: resampy>=0.2.2 in c:\users\sefun\anaconda3\lib\site-packages (from librosa) (0.2.2)
# Requirement already satisfied: soundfile>=0.9.0 in c:\users\sefun\anaconda3\lib\site-packages (from librosa) (0.10.3.post1)
# Requirement already satisfied: six>=1.3 in c:\users\sefun\anaconda3\lib\site-packages (from librosa) (1.14.0)
# Requirement already satisfied: llvmlite<0.32.0,>=0.31.0dev0 in c:\users\sefun\anaconda3\lib\site-packages (from numba>=0.43.0->librosa) (0.31.0)
# Requirement already satisfied: setuptools in c:\users\sefun\anaconda3\lib\site-packages (from numba>=0.43.0->librosa) (45.2.0.post20200210)
# Requirement already satisfied: cffi>=1.0 in c:\users\sefun\anaconda3\lib\site-packages (from soundfile>=0.9.0->librosa) (1.14.0)
# Requirement already satisfied: pycparser in c:\users\sefun\anaconda3\lib\site-packages (from cffi>=1.0->soundfile>=0.9.0->librosa) (2.19)
# Note: you may need to restart the kernel to use updated packages.

# %%
import tensorflow as tf
import IPython.display as ipd
import librosa

# %%
#importing files as from wav
data, sampling_rate = librosa.load('S4A04095_20190302_103255.wav')

# %%
import os
import pandas as pd
import librosa
import librosa.display
import glob 
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 4))
librosa.display.waveplot(data, sr=sampling_rate)

# %%
pip install pydub
# Out:
# Collecting pydub
#   Downloading pydub-0.24.1-py2.py3-none-any.whl (30 kB)
# Installing collected packages: pydub
# Successfully installed pydub-0.24.1
# Note: you may need to restart the kernel to use updated packages.

# %%
#importing wavfile 
from pydub import AudioSegment 

wav_file = AudioSegment.from_file(file="data/train/forrest_noise001.wav", format="wav")
wav_file = wav_file.set_channels(1)
wav_file.export("data/train/mono/forrest_noise001m.wav",format="wav")
# Out:
# <_io.BufferedRandom name='data/train/mono/forrest_noise001m.wav'>

# %%
#import wa file for spectrogram
import matplotlib.pyplot as plt
from scipy import signal
from scipy.io import wavfile

# %%
sample_rate, samples = wavfile.read('data/train/mono/forrest_noise001m.wav')

# %%
frequencies, times, spectrogram = signal.spectrogram(samples, sample_rate)

# %%
plt.pcolormesh(times, frequencies, spectrogram)
plt.imshow(spectrogram)

# %%
plt.pcolormesh(times, frequencies, spectrogram)
plt.imshow(spectrogram)
plt.ylabel('Frequency [Hz]')
plt.xlabel('Time [sec]')
plt.show()

# %%
import os
import matplotlib.pyplot as plt

#for loading and visualizing audio files
import librosa
import librosa.display

#to play audio
import IPython.display as ipd

#set path and view data
audio_fpath = "data/train/mono/"
audio_clips = os.listdir(audio_fpath)
print("No. of .wav files in audio folder = ",len(audio_clips))
# Out:
# No. of .wav files in audio folder =  1

# %%
#load audio data
x, sr = librosa.load(audio_fpath+audio_clips[0], sr=44100)

print(type(x), type(sr))
print(x.shape, sr)
# Out:
# <class 'numpy.ndarray'> <class 'int'>
# (79291800,) 44100

# %%
#view waveform
plt.figure(figsize=(14, 5))
librosa.display.waveplot(x[0:1000], sr=sr)

# %%
#view spectrogram
X = librosa.stft(x[0:100000])
Xdb = librosa.amplitude_to_db(abs(X))
plt.figure(figsize=(14, 5))
librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='hz')
plt.colorbar()

# %%
#view log spectrogram
plt.figure(figsize=(14, 5))
librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='log')
plt.colorbar()

# %%
audio_fpath = "data/train/mono/"
def specGen(audio_fpath):
    audio_clips = os.listdir(audio_fpath)
    for i in range(0, len(audio_clips)):
        
        x, sr = librosa.load(audio_fpath+audio_clips[i], sr=44100)
        
        X = librosa.stft(x[0:100000])
        Xdb = librosa.amplitude_to_db(abs(X))
        
        fig = plt.Figure()
        canvas = FigureCanvas(fig)
        ax = fig.add_subplot(111)
        plt.figure(figsize=(14, 5))
        librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='log')
        plt.colorbar()
        p = librosa.display.specshow(librosa.amplitude_to_db(out, ref=np.max), ax=ax, y_axis='log', x_axis='time')
        fig.savefig('spec.png')

# %%
        fig = plt.Figure()
        canvas = FigureCanvas(fig)
        ax = fig.add_subplot(111)
        
        plt.figure(figsize=(14, 5))
        librosa.display.specshow(Xdb, ax=ax, x_axis='time', y_axis='log')
        plt.colorbar()
        
        p = librosa.display.specshow(librosa.amplitude_to_db(out, ref=np.max), ax=ax, y_axis='log', x_axis='time')
        fig.savefig('spec.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-54ac3562bfa3> in <module>
#       1 fig = plt.Figure()
# ----> 2 canvas = FigureCanvas(fig)
#       3 ax = fig.add_subplot(111)
#       4
#       5 plt.figure(figsize=(14, 5))
#
# NameError: name 'FigureCanvas' is not defined
